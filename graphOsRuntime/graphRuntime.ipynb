# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x = ['Original(Windowns 11)    ','Version1(Windowns 11)' , 'Version1(Linux)' ]
y= [24887,7835,7133]

# %%
plt.bar(x,y)
plt.title('Runtime(ms)')
plt.show()

# %%
x = ['Original(Windowns 11)    ','Version2(Windowns 11)' , 'Version2(Linux)' ]
y= [24887,4338,3856]

# %%
plt.bar(x,y)
plt.title('Runtime(ms)')
plt.show()

# %%
x = ['dotnet run ' , 'dotnet run -c release' ]
y= [1595,796]

# %%
plt.bar(x,y)
plt.title('Runtime(ms)')
plt.show()
